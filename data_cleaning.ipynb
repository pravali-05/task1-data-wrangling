# %%
import pandas as pd

df = pd.read_csv("C:/Users/Kummetha Subbareddy/OneDrive/Documents/sample_sales_dataset.csv")
print(df.head())

print(df.isnull().sum())

df = df.dropna()
df = df.drop_duplicates()

df.to_csv("cleaned_sales_data.csv", index=False)
# Out:
#    CustomerID   Age Gender       City  PurchaseAmount
# 0         101  22.0      F  Hyderabad           250.0
# 1         102  25.0      M    Chennai           300.0
# 2         103   NaN      F  Bangalore           150.0
# 3         104  30.0      M  Hyderabad             NaN
# 4         105  28.0      F    Chennai           400.0
# CustomerID        0
# Age               2
# Gender            0
# City              0
# PurchaseAmount    1
# dtype: int64
